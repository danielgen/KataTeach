# %%
import torch
import torch.nn as nn
import numpy as np
from board import Board
from features import Features
from gamestate import GameState
from load_model import load_model  # This is an import from a file within the repo

# Function to parse coordinates
colstr = 'ABCDEFGHJKLMNOPQRST'
def parse_coord(s, board):
    if s == 'pass':
        return Board.PASS_LOC
    return board.loc(colstr.index(s[0].upper()), board.size - int(s[1:]))

def str_coord(loc, board):
    if loc == Board.PASS_LOC:
        return 'pass'
    x = board.loc_x(loc)
    y = board.loc_y(loc)
    return '%c%d' % (colstr[x], board.size - y)

# Load model
checkpoint_path = r"D:\KataGo\kata1-b28c512nbt-s9584861952-d4960414494\model.ckpt"
model, swa_model, other_state_dict = load_model(checkpoint_path, use_swa=False, device="cuda")
if swa_model is not None:
    model = swa_model

model.eval()
board_size = 19
gs = GameState(board_size, GameState.RULES_TT)

pla = Board.BLACK
loc = parse_coord('Q16', gs.board)
gs.board.play(pla, loc)
gs.moves.append((pla, loc))
gs.boards.append(gs.board.copy())

outputs = gs.get_model_outputs(model)
loc = outputs["genmove_result"]
pla = gs.board.pla
gs.board.play(pla, loc)
gs.moves.append((pla, loc))
gs.boards.append(gs.board.copy())
ret = str_coord(loc, gs.board)
# Out:
# D:\KataGo\python\load_model.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(checkpoint_file,map_location="cpu")

# %%
print(model)
# Out:
# Model(
#   (conv_spatial): Conv2d(22, 512, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#   (linear_global): Linear(in_features=19, out_features=512, bias=False)
#   (blocks): ModuleList(
#     (0-1): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (2): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (3-4): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (5): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (6-7): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (8): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (9-10): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (11): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (12-13): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (14): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (15-16): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (17): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (18-19): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (20): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (21-22): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (23): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (24-25): 2 x NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (26): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (convpool): KataConvAndGPool(
#               (conv1r): Conv2d(256, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (conv1g): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#               (normg): NormMask()
#               (actg): Mish(inplace=True)
#               (gpool): KataGPool()
#               (linear_g): Linear(in_features=192, out_features=192, bias=False)
#             )
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#         (1): ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#     (27): NestedBottleneckResBlock(
#       (normactconvp): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#       (blockstack): ModuleList(
#         (0-1): 2 x ResBlock(
#           (normactconv1): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#           (normactconv2): NormActConv(
#             (norm): NormMask()
#             (act): Mish(inplace=True)
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same, bias=False)
#           )
#         )
#       )
#       (normactconvq): NormActConv(
#         (norm): NormMask()
#         (act): Mish(inplace=True)
#         (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#       )
#     )
#   )
#   (norm_trunkfinal): BiasMask()
#   (act_trunkfinal): Mish()
#   (policy_head): PolicyHead(
#     (conv1p): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv1g): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (biasg): BiasMask()
#     (actg): Mish()
#     (gpool): KataGPool()
#     (linear_g): Linear(in_features=192, out_features=64, bias=False)
#     (linear_pass): Linear(in_features=192, out_features=64, bias=True)
#     (act_pass): Mish()
#     (linear_pass2): Linear(in_features=64, out_features=6, bias=False)
#     (bias2): BiasMask()
#     (act2): Mish()
#     (conv2p): Conv2d(64, 6, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#   )
#   (value_head): ValueHead(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (bias1): BiasMask()
#     (act1): Mish()
#     (gpool): KataValueHeadGPool()
#     (linear2): Linear(in_features=384, out_features=144, bias=True)
#     (act2): Mish()
#     (linear_valuehead): Linear(in_features=144, out_features=3, bias=True)
#     (linear_miscvaluehead): Linear(in_features=144, out_features=10, bias=True)
#     (linear_moremiscvaluehead): Linear(in_features=144, out_features=8, bias=True)
#     (conv_ownership): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_scoring): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_futurepos): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_seki): Conv2d(512, 4, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (linear_s2): Linear(in_features=384, out_features=128, bias=True)
#     (linear_s2off): Linear(in_features=1, out_features=128, bias=False)
#     (linear_s2par): Linear(in_features=1, out_features=128, bias=False)
#     (linear_s3): Linear(in_features=128, out_features=8, bias=True)
#     (linear_smix): Linear(in_features=384, out_features=8, bias=True)
#   )
#   (norm_intermediate_trunkfinal): NormMask()
#   (act_intermediate_trunkfinal): Mish()
#   (intermediate_policy_head): PolicyHead(
#     (conv1p): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv1g): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (biasg): BiasMask()
#     (actg): Mish()
#     (gpool): KataGPool()
#     (linear_g): Linear(in_features=192, out_features=64, bias=False)
#     (linear_pass): Linear(in_features=192, out_features=64, bias=True)
#     (act_pass): Mish()
#     (linear_pass2): Linear(in_features=64, out_features=6, bias=False)
#     (bias2): BiasMask()
#     (act2): Mish()
#     (conv2p): Conv2d(64, 6, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#   )
#   (intermediate_value_head): ValueHead(
#     (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (bias1): BiasMask()
#     (act1): Mish()
#     (gpool): KataValueHeadGPool()
#     (linear2): Linear(in_features=384, out_features=144, bias=True)
#     (act2): Mish()
#     (linear_valuehead): Linear(in_features=144, out_features=3, bias=True)
#     (linear_miscvaluehead): Linear(in_features=144, out_features=10, bias=True)
#     (linear_moremiscvaluehead): Linear(in_features=144, out_features=8, bias=True)
#     (conv_ownership): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_scoring): Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_futurepos): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (conv_seki): Conv2d(512, 4, kernel_size=(1, 1), stride=(1, 1), padding=same, bias=False)
#     (linear_s2): Linear(in_features=384, out_features=128, bias=True)
#     (linear_s2off): Linear(in_features=1, out_features=128, bias=False)
#     (linear_s2par): Linear(in_features=1, out_features=128, bias=False)
#     (linear_s3): Linear(in_features=128, out_features=8, bias=True)
#     (linear_smix): Linear(in_features=384, out_features=8, bias=True)
#   )
# )

# %%
from torchinfo import summary
import torch

B = 1
C = 22          # spatial input planes
board_size = 19
global_feats = 19  # from linear_global.in_features

# Dummy inputs
spatial = torch.zeros((B, C, board_size, board_size), device="cuda")
globalf = torch.zeros((B, global_feats), device="cuda")

# Print full model summary
summary(
    model,
    input_data=(spatial, globalf),
    device="cuda",
    depth=5,            # increase to see full nested structure
    col_names=("input_size", "output_size", "num_params", "kernel_size", "mult_adds")
)
# Out:
# ====================================================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# ====================================================================================================================================================================================
# Model                                                   [1, 22, 19, 19]           [1, 6, 362]               --                        --                        --
# ├─Conv2d: 1-1                                           [1, 22, 19, 19]           [1, 512, 19, 19]          101,376                   [3, 3]                    36,596,736
# ├─Linear: 1-2                                           [1, 19]                   [1, 512]                  9,728                     --                        9,728
# ├─ModuleList: 1-3                                       --                        --                        --                        --                        --
# │    └─NestedBottleneckResBlock: 2-1                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-1                            [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-1                          [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-2                              [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-3                            [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-2                             --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-4                          [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-1                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-2                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-5                          [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-3                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-4                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-3                            [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-6                          [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-7                              [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-8                            [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-2                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-4                            [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-9                          [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-10                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-11                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-5                             --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-12                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-5                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-6                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-13                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-7                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-8                  [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-6                            [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-14                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-15                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-16                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-3                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-7                            [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-17                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-18                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-19                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-8                             --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-20                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-9                  [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-10                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# │    │    │    └─ResBlock: 4-21                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-11                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-12                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-9                            [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-22                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-23                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-24                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-4                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-10                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-25                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-26                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-27                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-11                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-28                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-13                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-14                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-29                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-15                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-16                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-12                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-30                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-31                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-32                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-5                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-13                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-33                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-34                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-35                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-14                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-36                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-17                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-18                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-37                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-19                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-20                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-15                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-38                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-39                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-40                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-6                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-16                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-41                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-42                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-43                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-17                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-44                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-21                 [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-22                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# │    │    │    └─ResBlock: 4-45                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-23                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-24                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-18                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-46                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-47                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-48                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-7                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-19                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-49                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-50                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-51                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-20                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-52                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-25                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-26                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-53                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-27                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-28                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-21                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-54                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-55                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-56                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-8                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-22                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-57                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-58                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-59                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-23                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-60                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-29                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-30                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-61                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-31                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-32                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-24                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-62                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-63                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-64                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-9                    [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-25                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-65                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-66                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-67                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-26                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-68                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-33                 [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-34                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# │    │    │    └─ResBlock: 4-69                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-35                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-36                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-27                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-70                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-71                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-72                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-10                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-28                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-73                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-74                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-75                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-29                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-76                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-37                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-38                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-77                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-39                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-40                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-30                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-78                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-79                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-80                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-11                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-31                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-81                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-82                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-83                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-32                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-84                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-41                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-42                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-85                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-43                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-44                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-33                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-86                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-87                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-88                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-12                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-34                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-89                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-90                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-91                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-35                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-92                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-45                 [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-46                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# │    │    │    └─ResBlock: 4-93                         [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-47                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-48                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-36                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-94                         [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-95                             [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-96                           [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-13                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-37                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-97                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-98                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-99                           [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-38                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-100                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-49                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-50                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-101                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-51                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-52                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-39                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-102                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-103                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-104                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-14                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-40                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-105                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-106                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-107                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-41                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-108                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-53                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-54                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-109                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-55                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-56                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-42                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-110                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-111                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-112                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-15                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-43                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-113                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-114                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-115                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-44                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-116                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-57                 [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-58                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# │    │    │    └─ResBlock: 4-117                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-59                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-60                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-45                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-118                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-119                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-120                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-16                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-46                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-121                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-122                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-123                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-47                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-124                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-61                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-62                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-125                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-63                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-64                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-48                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-126                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-127                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-128                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-17                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-49                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-129                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-130                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-131                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-50                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-132                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-65                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-66                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-133                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-67                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-68                 [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-51                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-134                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-135                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-136                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-18                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-52                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-137                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-138                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-139                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-53                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-140                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-69                 [1, 256, 19, 19]          [1, 192, 19, 19]          627,328                   --                        212,963,328
# │    │    │    │    └─NormActConv: 5-70                 [1, 192, 19, 19]          [1, 256, 19, 19]          442,752                   --                        159,694,848
# ...
# │    │    │    │    └─NormActConv: 5-108                [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-81                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-214                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-215                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-216                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    └─NestedBottleneckResBlock: 2-28                   [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    └─NormActConv: 3-82                           [1, 512, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-217                        [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# │    │    │    └─Mish: 4-218                            [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-219                          [1, 512, 19, 19]          [1, 256, 19, 19]          131,072                   [1, 1]                    47,316,992
# │    │    └─ModuleList: 3-83                            --                        --                        --                        --                        --
# │    │    │    └─ResBlock: 4-220                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-109                [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-110                [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    └─ResBlock: 4-221                        [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    │    └─NormActConv: 5-111                [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    │    │    └─NormActConv: 5-112                [1, 256, 19, 19]          [1, 256, 19, 19]          590,336                   --                        212,926,464
# │    │    └─NormActConv: 3-84                           [1, 256, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# │    │    │    └─NormMask: 4-222                        [1, 256, 19, 19]          [1, 256, 19, 19]          512                       --                        --
# │    │    │    └─Mish: 4-223                            [1, 256, 19, 19]          [1, 256, 19, 19]          --                        --                        --
# │    │    │    └─Conv2d: 4-224                          [1, 256, 19, 19]          [1, 512, 19, 19]          131,072                   [1, 1]                    47,316,992
# ├─NormMask: 1-4                                         [1, 512, 19, 19]          [1, 512, 19, 19]          1,024                     --                        --
# ├─Mish: 1-5                                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# ├─PolicyHead: 1-6                                       [1, 512, 19, 19]          [1, 6, 362]               --                        --                        --
# │    └─Conv2d: 2-29                                     [1, 512, 19, 19]          [1, 64, 19, 19]           32,768                    [1, 1]                    11,829,248
# │    └─Conv2d: 2-30                                     [1, 512, 19, 19]          [1, 64, 19, 19]           32,768                    [1, 1]                    11,829,248
# │    └─BiasMask: 2-31                                   [1, 64, 19, 19]           [1, 64, 19, 19]           64                        --                        --
# │    └─Mish: 2-32                                       [1, 64, 19, 19]           [1, 64, 19, 19]           --                        --                        --
# │    └─KataGPool: 2-33                                  [1, 64, 19, 19]           [1, 192, 1, 1]            --                        --                        --
# │    └─Linear: 2-34                                     [1, 192]                  [1, 64]                   12,352                    --                        12,352
# │    └─Mish: 2-35                                       [1, 64]                   [1, 64]                   --                        --                        --
# │    └─Linear: 2-36                                     [1, 64]                   [1, 6]                    384                       --                        384
# │    └─Linear: 2-37                                     [1, 192]                  [1, 64]                   12,288                    --                        12,288
# │    └─BiasMask: 2-38                                   [1, 64, 19, 19]           [1, 64, 19, 19]           64                        --                        --
# │    └─Mish: 2-39                                       [1, 64, 19, 19]           [1, 64, 19, 19]           --                        --                        --
# │    └─Conv2d: 2-40                                     [1, 64, 19, 19]           [1, 6, 19, 19]            384                       [1, 1]                    138,624
# ├─ValueHead: 1-7                                        [1, 512, 19, 19]          [1, 3]                    --                        --                        --
# │    └─Conv2d: 2-41                                     [1, 512, 19, 19]          [1, 128, 19, 19]          65,536                    [1, 1]                    23,658,496
# │    └─BiasMask: 2-42                                   [1, 128, 19, 19]          [1, 128, 19, 19]          128                       --                        --
# │    └─Mish: 2-43                                       [1, 128, 19, 19]          [1, 128, 19, 19]          --                        --                        --
# │    └─KataValueHeadGPool: 2-44                         [1, 128, 19, 19]          [1, 384, 1, 1]            --                        --                        --
# │    └─Linear: 2-45                                     [1, 384]                  [1, 144]                  55,440                    --                        55,440
# │    └─Mish: 2-46                                       [1, 144]                  [1, 144]                  --                        --                        --
# │    └─Linear: 2-47                                     [1, 144]                  [1, 3]                    435                       --                        435
# │    └─Linear: 2-48                                     [1, 144]                  [1, 10]                   1,450                     --                        1,450
# │    └─Linear: 2-49                                     [1, 144]                  [1, 8]                    1,160                     --                        1,160
# │    └─Conv2d: 2-50                                     [1, 128, 19, 19]          [1, 1, 19, 19]            128                       [1, 1]                    46,208
# │    └─Conv2d: 2-51                                     [1, 128, 19, 19]          [1, 1, 19, 19]            128                       [1, 1]                    46,208
# │    └─Conv2d: 2-52                                     [1, 512, 19, 19]          [1, 2, 19, 19]            1,024                     [1, 1]                    369,664
# │    └─Conv2d: 2-53                                     [1, 512, 19, 19]          [1, 4, 19, 19]            2,048                     [1, 1]                    739,328
# │    └─Linear: 2-54                                     [1, 384]                  [1, 128]                  49,280                    --                        49,280
# │    └─Linear: 2-55                                     [1, 842, 1]               [1, 842, 128]             128                       --                        128
# │    └─Linear: 2-56                                     [1, 842, 1]               [1, 842, 128]             128                       --                        128
# │    └─Mish: 2-57                                       [1, 842, 128]             [1, 842, 128]             --                        --                        --
# │    └─Linear: 2-58                                     [1, 842, 128]             [1, 842, 8]               1,032                     --                        1,032
# │    └─Linear: 2-59                                     [1, 384]                  [1, 8]                    3,080                     --                        3,080
# ├─BiasMask: 1-8                                         [1, 512, 19, 19]          [1, 512, 19, 19]          512                       --                        --
# ├─Mish: 1-9                                             [1, 512, 19, 19]          [1, 512, 19, 19]          --                        --                        --
# ├─PolicyHead: 1-10                                      [1, 512, 19, 19]          [1, 6, 362]               --                        --                        --
# │    └─Conv2d: 2-60                                     [1, 512, 19, 19]          [1, 64, 19, 19]           32,768                    [1, 1]                    11,829,248
# │    └─Conv2d: 2-61                                     [1, 512, 19, 19]          [1, 64, 19, 19]           32,768                    [1, 1]                    11,829,248
# │    └─BiasMask: 2-62                                   [1, 64, 19, 19]           [1, 64, 19, 19]           64                        --                        --
# │    └─Mish: 2-63                                       [1, 64, 19, 19]           [1, 64, 19, 19]           --                        --                        --
# │    └─KataGPool: 2-64                                  [1, 64, 19, 19]           [1, 192, 1, 1]            --                        --                        --
# │    └─Linear: 2-65                                     [1, 192]                  [1, 64]                   12,352                    --                        12,352
# │    └─Mish: 2-66                                       [1, 64]                   [1, 64]                   --                        --                        --
# │    └─Linear: 2-67                                     [1, 64]                   [1, 6]                    384                       --                        384
# │    └─Linear: 2-68                                     [1, 192]                  [1, 64]                   12,288                    --                        12,288
# │    └─BiasMask: 2-69                                   [1, 64, 19, 19]           [1, 64, 19, 19]           64                        --                        --
# │    └─Mish: 2-70                                       [1, 64, 19, 19]           [1, 64, 19, 19]           --                        --                        --
# │    └─Conv2d: 2-71                                     [1, 64, 19, 19]           [1, 6, 19, 19]            384                       [1, 1]                    138,624
# ├─ValueHead: 1-11                                       [1, 512, 19, 19]          [1, 3]                    --                        --                        --
# │    └─Conv2d: 2-72                                     [1, 512, 19, 19]          [1, 128, 19, 19]          65,536                    [1, 1]                    23,658,496
# │    └─BiasMask: 2-73                                   [1, 128, 19, 19]          [1, 128, 19, 19]          128                       --                        --
# │    └─Mish: 2-74                                       [1, 128, 19, 19]          [1, 128, 19, 19]          --                        --                        --
# │    └─KataValueHeadGPool: 2-75                         [1, 128, 19, 19]          [1, 384, 1, 1]            --                        --                        --
# │    └─Linear: 2-76                                     [1, 384]                  [1, 144]                  55,440                    --                        55,440
# │    └─Mish: 2-77                                       [1, 144]                  [1, 144]                  --                        --                        --
# │    └─Linear: 2-78                                     [1, 144]                  [1, 3]                    435                       --                        435
# │    └─Linear: 2-79                                     [1, 144]                  [1, 10]                   1,450                     --                        1,450
# │    └─Linear: 2-80                                     [1, 144]                  [1, 8]                    1,160                     --                        1,160
# │    └─Conv2d: 2-81                                     [1, 128, 19, 19]          [1, 1, 19, 19]            128                       [1, 1]                    46,208
# │    └─Conv2d: 2-82                                     [1, 128, 19, 19]          [1, 1, 19, 19]            128                       [1, 1]                    46,208
# │    └─Conv2d: 2-83                                     [1, 512, 19, 19]          [1, 2, 19, 19]            1,024                     [1, 1]                    369,664
# │    └─Conv2d: 2-84                                     [1, 512, 19, 19]          [1, 4, 19, 19]            2,048                     [1, 1]                    739,328
# │    └─Linear: 2-85                                     [1, 384]                  [1, 128]                  49,280                    --                        49,280
# │    └─Linear: 2-86                                     [1, 842, 1]               [1, 842, 128]             128                       --                        128
# │    └─Linear: 2-87                                     [1, 842, 1]               [1, 842, 128]             128                       --                        128
# │    └─Mish: 2-88                                       [1, 842, 128]             [1, 842, 128]             --                        --                        --
# │    └─Linear: 2-89                                     [1, 842, 128]             [1, 842, 8]               1,032                     --                        1,032
# │    └─Linear: 2-90                                     [1, 384]                  [1, 8]                    3,080                     --                        3,080
# ====================================================================================================================================================================================
# Total params: 73,162,378
# Trainable params: 73,162,378
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 26.15
# ====================================================================================================================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 300.87
# Params size (MB): 292.65
# Estimated Total Size (MB): 593.55
# ====================================================================================================================================================================================
